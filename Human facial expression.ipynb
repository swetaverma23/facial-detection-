# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd My Drive
# Out:
# /gdrive/My Drive

# %%
ls
# Out:
#  1.04.19.gdoc       'Getting started.pdf'   opencv.rar       'vpr kar.pdf'
#  Classroom/          marklist.pdf           opencv.zip       'vpr sb.pdf'
# 'Colab Notebooks'/   opencv/                Untitled1.ipynb   vprSB.pdf

# %%
#!unzip -q opencv.zip -d opencv/

# %%
ls
# Out:
#  1.04.19.gdoc       'Getting started.pdf'   opencv.rar       'vpr kar.pdf'
#  Classroom/          marklist.pdf           opencv.zip       'vpr sb.pdf'
# 'Colab Notebooks'/   opencv/                Untitled1.ipynb   vprSB.pdf

# %%
cd opencv
# Out:
# /gdrive/My Drive/opencv

# %%
ls
# Out:
# opencv/

# %%
cd opencv
# Out:
# /gdrive/My Drive/opencv/opencv

# %%
ls
# Out:
#  1.jpg               face_recognition_nocomment.py         opencv.zip
#  2.jpg               haarcascade_eye.xml                   test/
#  3.jpg               haarcascade_frontalface_default.xml   train/
#  cnn_model.h5       'image transformation.ipynb'           Untitled.ipynb
#  expressions.ipynb   opencv/

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
# Out:
# Using TensorFlow backend.

# %%
cnn_model = Sequential()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0705 01:11:01.144781 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
cnn_model.add(Conv2D(128 ,4, 4 , input_shape = (128,128,3) , activation = "relu"))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (4, 4), input_shape=(128, 128,..., activation="relu")`
#   """Entry point for launching an IPython kernel.
# W0705 01:11:03.525679 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0705 01:11:03.532954 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
'''cnn_model.add(MaxPooling2D(pool_size = (2,2)))
cnn_model.add(Conv2D(128 ,4, 4, activation = "relu"))
cnn_model.add(MaxPooling2D(pool_size = (2,2)))
cnn_model.add(Conv2D(128 ,4, 4, activation = "relu"))'''
cnn_model.add(MaxPooling2D(pool_size = (2,2)))
# Out:
# W0705 01:11:05.021289 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn_model.add(Flatten())

# %%
cnn_model.add(Dense(init = "random_uniform" , activation = "relu" , output_dim = 250))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=250, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
#cnn_model.add(Dense(init = "random_uniform" , activation = "relu" , output_dim = 250))

# %%
#cnn_model.add(Dense(init = "random_uniform" , activation = "relu" , output_dim = 250))

# %%
cnn_model.add(Dense(init = "random_uniform" , activation = "softmax" , output_dim = 4))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="softmax", units=4, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
cnn_model.compile(optimizer= "adam", loss = "categorical_crossentropy", metrics= ["accuracy"])
# Out:
# W0705 01:11:12.167321 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0705 01:11:12.199337 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range = 0.2,
        zoom_range = 0.2)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
x_train = test_datagen.flow_from_directory(
        'train/',
        target_size=(128, 128),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 7684 images belonging to 4 classes.

# %%
x_test = test_datagen.flow_from_directory(
        'test/',
        target_size=(128,128),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 356 images belonging to 4 classes.

# %%
cnn_model.fit_generator(
        x_train,
        steps_per_epoch = 900,    #no of images / batch_size
        epochs = 5,
        validation_data = x_test,
        validation_steps = 12)    #no of images(test) / batch size
# Out:
# W0705 01:11:21.327702 140498666817408 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0705 01:11:21.383856 140498666817408 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/5
# 900/900 [==============================] - 293s 326ms/step - loss: 0.1496 - acc: 0.9569 - val_loss: 0.1916 - val_acc: 0.9438
# Epoch 2/5
# 900/900 [==============================] - 109s 121ms/step - loss: 0.0201 - acc: 0.9940 - val_loss: 0.1781 - val_acc: 0.9466
# Epoch 3/5
# 900/900 [==============================] - 109s 121ms/step - loss: 0.0151 - acc: 0.9957 - val_loss: 0.2632 - val_acc: 0.9354
# Epoch 4/5
# 900/900 [==============================] - 109s 121ms/step - loss: 0.0042 - acc: 0.9987 - val_loss: 0.3394 - val_acc: 0.9298
# Epoch 5/5
# 900/900 [==============================] - 109s 121ms/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.2940 - val_acc: 0.9438

# %%
x_train.class_indices
# Out:
# {'angry': 0, 'happy': 1, 'normal': 2, 'sad': 3}

# %%
cnn_model.save("cnn_model.h5")

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import cv2
model = load_model('cnn_model.h5')
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
from skimage.io import imread
from skimage.transform import resize

def detect(frame):
    try:
        img = resize(frame,(128,128))
        img = np.array([img])
        if(np.max(img)>1):
            img = img/255.0
        prediction = model.predict_classes(img)
        print(prediction)
    except AttributeError:
        print("shape not found")

frame=cv2.imread("4.jpg")
detect(frame)
# Out:
# [1]
